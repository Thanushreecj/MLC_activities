# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanushreecj/MLC_activities/blob/main/WSS_CWE_vs_CVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages
import pandas as pd
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR='/content/drive/My Drive/Colab Notebooks/data'
datafile='699.csv'
filename=DIR+'/'+datafile

# %%
os.chdir(DIR)
df = pd.read_csv(datafile)
df
# Out:
#                                                  CWE-ID  Name  \
# 15    External Control of System or Configuration Se...  Base
# 22    Improper Limitation of a Pathname to a Restric...  Base
# 41              Improper Resolution of Path Equivalence  Base
# 59    Improper Link Resolution Before File Access ('...  Base
# 66    Improper Handling of File Names that Identify ...  Base
# ...                                                 ...   ...
# 1335                 Incorrect Bitwise Shift of Integer  Base
# 1339  Insufficient Precision or Accuracy of a Real N...  Base
# 1341       Multiple Releases of Same Resource or Handle  Base
# 1389  Incorrect Parsing of Numbers with Different Ra...  Base
# 1392                         Use of Default Credentials  Base
#
#      Weakness Abstraction                                             Status  \
# 15             Incomplete  One or more system settings or configuration e...
# ...

# %%
#to display only the row id 15
df.iloc[15]
# Out:
# CWE-ID                                                Missing XML Validation
# Name                                                                    Base
# Weakness Abstraction                                                   Draft
# Status                     The product accepts XML from an untrusted sour...
# Description                Most successful attacks begin with a violation...
# Extended Description       ::NATURE:ChildOf:CWE ID:1286:VIEW ID:1000:ORDI...
# Related Weaknesses                                    ::ORDINALITY:Primary::
# Weakness Ordinalities      ::LANGUAGE CLASS:Not Language-Specific:LANGUAG...
# Applicable Platforms                                                     NaN
# Background Details                                                       NaN
# Alternate Terms                                     ::PHASE:Implementation::
# Modes Of Introduction                                                    NaN
# ...

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(df)
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
df[df["Description"].str.contains('auth',case=False,na=False)]
# Out:
#                                                  CWE-ID  Name  \
# 301     Reflection Attack in an Authentication Protocol  Base
# 303   Incorrect Implementation of Authentication Alg...  Base
# 322          Key Exchange without Entity Authentication  Base
# 360                          Trust of System Event Data  Base
# 421   Race Condition During Access to Alternate Channel  Base
# 425                  Direct Request ('Forced Browsing')  Base
# 426                               Untrusted Search Path  Base
# 470   Use of Externally-Controlled Input to Select C...  Base
# 472   External Control of Assumed-Immutable Web Para...  Base
# 497   Exposure of Sensitive System Information to an...  Base
# 524       Use of Cache Containing Sensitive Information  Base
# 551   Incorrect Behavior Order: Authorization Before...  Base
# 603                   Use of Client-Side Authentication  Base
# 639    Authorization Bypass Through User-Controlled Key  Base
# ...
